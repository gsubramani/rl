# %%
# !wandb login
# Out:
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: Currently logged in as: guru-subramani-g-s (guru-subramani) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# The token `colab` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `colab`

# %% [markdown]
# # 🤗 x 🦾: Training ACT with LeRobot Notebook
#
# Welcome to the **LeRobot ACT training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `ACT` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `ACT` policy for 100,000 steps typically takes **about 1.5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer.
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.12.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.1.3)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (24.2)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.3) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.3) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.3) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (2.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (7.1.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.3) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.3) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (12.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.3) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.3) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.3) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.3) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.3.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (6.33.2)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.12.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.48.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.3) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.3) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.3) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.3) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.3) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.3) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.3) (0.2.14)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.3-0.editable-py3-none-any.whl size=15676 sha256=3817effad6d2a1c9d17eb1ad417dda123fe4f8b7e25b7eaa66846de9e82d1895
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yy5s4g2f/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.3
#     Uninstalling lerobot-0.4.3:
#       Successfully uninstalled lerobot-0.4.3
# Successfully installed lerobot-0.4.3

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %% [markdown]
# ## Start training ACT with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_train.py \
  --dataset.repo_id=gsubramani/move-stuff-1 \
  --policy.type=act \
  --output_dir=outputs/train/move-stuff-1-train \
  --job_name=move-stuff-1-job \
  --policy.device=cuda \
  --policy.repo_id=gsubramani/move-stuff-1 \
  --batch_size=12 \
  --wandb.enable=true
# Out:
# INFO 2025-12-18 07:14:38 ot_train.py:164 {'batch_size': 12,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'gsubramani/move-stuff-1',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'move-stuff-1-job',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/move-stuff-1-train',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'gsubramani/move-stuff-1',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 100000,
#  'tolerance_s': 0.0001,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-18 07:14:39 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-18 07:14:39 db_utils.py:103 Track this run --> https://wandb.ai/guru-subramani/lerobot/runs/brg5um21
# INFO 2025-12-18 07:14:39 ot_train.py:184 Creating dataset
# INFO 2025-12-18 07:14:40 ot_train.py:203 Creating policy
# INFO 2025-12-18 07:14:41 ot_train.py:248 Creating optimizer and scheduler
# INFO 2025-12-18 07:14:41 ot_train.py:260 Output dir: outputs/train/move-stuff-1-train
# INFO 2025-12-18 07:14:41 ot_train.py:267 cfg.steps=100000 (100K)
# INFO 2025-12-18 07:14:41 ot_train.py:268 dataset.num_frames=22430 (22K)
# INFO 2025-12-18 07:14:41 ot_train.py:269 dataset.num_episodes=50
# INFO 2025-12-18 07:14:41 ot_train.py:272 Effective batch size: 12 x 1 = 12
# INFO 2025-12-18 07:14:41 ot_train.py:273 num_learnable_params=51597190 (52M)
# INFO 2025-12-18 07:14:41 ot_train.py:274 num_total_params=51597190 (52M)
# INFO 2025-12-18 07:14:41 ot_train.py:330 Start offline training on a fixed dataset
# INFO 2025-12-18 07:16:17 ot_train.py:357 step:200 smpl:2K ep:5 epch:0.11 loss:6.480 grdn:129.684 lr:1.0e-05 updt_s:0.438 data_s:0.042
# INFO 2025-12-18 07:17:46 ot_train.py:357 step:400 smpl:5K ep:11 epch:0.21 loss:2.818 grdn:69.024 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:19:16 ot_train.py:357 step:600 smpl:7K ep:16 epch:0.32 loss:2.371 grdn:61.574 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:20:46 ot_train.py:357 step:800 smpl:10K ep:21 epch:0.43 loss:2.114 grdn:55.988 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:22:15 ot_train.py:357 step:1K smpl:12K ep:27 epch:0.53 loss:1.883 grdn:52.497 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:23:45 ot_train.py:357 step:1K smpl:14K ep:32 epch:0.64 loss:1.691 grdn:49.190 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:25:15 ot_train.py:357 step:1K smpl:17K ep:37 epch:0.75 loss:1.511 grdn:46.662 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:26:44 ot_train.py:357 step:2K smpl:19K ep:43 epch:0.86 loss:1.367 grdn:45.387 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:28:14 ot_train.py:357 step:2K smpl:22K ep:48 epch:0.96 loss:1.208 grdn:41.735 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:29:45 ot_train.py:357 step:2K smpl:24K ep:53 epch:1.07 loss:1.078 grdn:39.294 lr:1.0e-05 updt_s:0.420 data_s:0.037
# INFO 2025-12-18 07:31:15 ot_train.py:357 step:2K smpl:26K ep:59 epch:1.18 loss:0.979 grdn:37.021 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:32:45 ot_train.py:357 step:2K smpl:29K ep:64 epch:1.28 loss:0.877 grdn:35.767 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:34:14 ot_train.py:357 step:3K smpl:31K ep:70 epch:1.39 loss:0.801 grdn:33.882 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:35:44 ot_train.py:357 step:3K smpl:34K ep:75 epch:1.50 loss:0.720 grdn:30.975 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:37:14 ot_train.py:357 step:3K smpl:36K ep:80 epch:1.60 loss:0.660 grdn:29.966 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:38:43 ot_train.py:357 step:3K smpl:38K ep:86 epch:1.71 loss:0.613 grdn:28.592 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:40:13 ot_train.py:357 step:3K smpl:41K ep:91 epch:1.82 loss:0.560 grdn:26.355 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:41:43 ot_train.py:357 step:4K smpl:43K ep:96 epch:1.93 loss:0.520 grdn:25.939 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:43:14 ot_train.py:357 step:4K smpl:46K ep:102 epch:2.03 loss:0.487 grdn:24.655 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 07:44:44 ot_train.py:357 step:4K smpl:48K ep:107 epch:2.14 loss:0.453 grdn:23.204 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:46:13 ot_train.py:357 step:4K smpl:50K ep:112 epch:2.25 loss:0.437 grdn:22.725 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:47:43 ot_train.py:357 step:4K smpl:53K ep:118 epch:2.35 loss:0.407 grdn:21.782 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:49:13 ot_train.py:357 step:5K smpl:55K ep:123 epch:2.46 loss:0.389 grdn:21.184 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:50:42 ot_train.py:357 step:5K smpl:58K ep:128 epch:2.57 loss:0.374 grdn:20.848 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:52:12 ot_train.py:357 step:5K smpl:60K ep:134 epch:2.67 loss:0.358 grdn:20.076 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:53:42 ot_train.py:357 step:5K smpl:62K ep:139 epch:2.78 loss:0.341 grdn:19.857 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:55:11 ot_train.py:357 step:5K smpl:65K ep:144 epch:2.89 loss:0.332 grdn:19.202 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 07:56:41 ot_train.py:357 step:6K smpl:67K ep:150 epch:3.00 loss:0.328 grdn:18.674 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 07:58:12 ot_train.py:357 step:6K smpl:70K ep:155 epch:3.10 loss:0.311 grdn:17.981 lr:1.0e-05 updt_s:0.418 data_s:0.038
# INFO 2025-12-18 07:59:42 ot_train.py:357 step:6K smpl:72K ep:160 epch:3.21 loss:0.299 grdn:17.531 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:01:11 ot_train.py:357 step:6K smpl:74K ep:166 epch:3.32 loss:0.290 grdn:17.054 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:02:41 ot_train.py:357 step:6K smpl:77K ep:171 epch:3.42 loss:0.295 grdn:17.120 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:04:10 ot_train.py:357 step:7K smpl:79K ep:177 epch:3.53 loss:0.282 grdn:17.017 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:05:40 ot_train.py:357 step:7K smpl:82K ep:182 epch:3.64 loss:0.272 grdn:16.510 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:07:10 ot_train.py:357 step:7K smpl:84K ep:187 epch:3.74 loss:0.267 grdn:16.914 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:08:40 ot_train.py:357 step:7K smpl:86K ep:193 epch:3.85 loss:0.259 grdn:16.519 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:10:09 ot_train.py:357 step:7K smpl:89K ep:198 epch:3.96 loss:0.250 grdn:16.339 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:11:40 ot_train.py:357 step:8K smpl:91K ep:203 epch:4.07 loss:0.244 grdn:16.119 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 08:13:10 ot_train.py:357 step:8K smpl:94K ep:209 epch:4.17 loss:0.232 grdn:15.630 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:14:40 ot_train.py:357 step:8K smpl:96K ep:214 epch:4.28 loss:0.231 grdn:15.698 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:16:09 ot_train.py:357 step:8K smpl:98K ep:219 epch:4.39 loss:0.225 grdn:15.429 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:17:39 ot_train.py:357 step:8K smpl:101K ep:225 epch:4.49 loss:0.212 grdn:14.706 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:19:09 ot_train.py:357 step:9K smpl:103K ep:230 epch:4.60 loss:0.211 grdn:14.990 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:20:38 ot_train.py:357 step:9K smpl:106K ep:235 epch:4.71 loss:0.210 grdn:14.821 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:22:08 ot_train.py:357 step:9K smpl:108K ep:241 epch:4.81 loss:0.206 grdn:14.795 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:23:38 ot_train.py:357 step:9K smpl:110K ep:246 epch:4.92 loss:0.203 grdn:14.639 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:25:09 ot_train.py:357 step:9K smpl:113K ep:251 epch:5.03 loss:0.202 grdn:14.577 lr:1.0e-05 updt_s:0.417 data_s:0.037
# INFO 2025-12-18 08:26:38 ot_train.py:357 step:10K smpl:115K ep:257 epch:5.14 loss:0.189 grdn:14.271 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:28:08 ot_train.py:357 step:10K smpl:118K ep:262 epch:5.24 loss:0.193 grdn:13.950 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:29:38 ot_train.py:357 step:10K smpl:120K ep:267 epch:5.35 loss:0.189 grdn:14.161 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:31:07 ot_train.py:357 step:10K smpl:122K ep:273 epch:5.46 loss:0.187 grdn:13.480 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:32:37 ot_train.py:357 step:10K smpl:125K ep:278 epch:5.56 loss:0.182 grdn:13.345 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:34:07 ot_train.py:357 step:11K smpl:127K ep:284 epch:5.67 loss:0.184 grdn:12.962 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:35:36 ot_train.py:357 step:11K smpl:130K ep:289 epch:5.78 loss:0.178 grdn:13.168 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:37:06 ot_train.py:357 step:11K smpl:132K ep:294 epch:5.88 loss:0.178 grdn:13.117 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:38:35 ot_train.py:357 step:11K smpl:134K ep:300 epch:5.99 loss:0.178 grdn:13.273 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:40:07 ot_train.py:357 step:11K smpl:137K ep:305 epch:6.10 loss:0.173 grdn:13.134 lr:1.0e-05 updt_s:0.417 data_s:0.037
# INFO 2025-12-18 08:41:36 ot_train.py:357 step:12K smpl:139K ep:310 epch:6.21 loss:0.173 grdn:12.854 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:43:06 ot_train.py:357 step:12K smpl:142K ep:316 epch:6.31 loss:0.165 grdn:12.835 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:44:35 ot_train.py:357 step:12K smpl:144K ep:321 epch:6.42 loss:0.163 grdn:12.129 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:46:05 ot_train.py:357 step:12K smpl:146K ep:326 epch:6.53 loss:0.162 grdn:12.660 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08:47:35 ot_train.py:357 step:12K smpl:149K ep:332 epch:6.63 loss:0.165 grdn:12.240 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 08:49:04 ot_train.py:357 step:13K smpl:151K ep:337 epch:6.74 loss:0.165 grdn:12.572 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 08
lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:14:24 ot_train.py:357 step:24K smpl:288K ep:642 epch:12.84 loss:0.111 grdn:9.128 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:15:54 ot_train.py:357 step:24K smpl:290K ep:647 epch:12.95 loss:0.109 grdn:8.867 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:17:25 ot_train.py:357 step:24K smpl:293K ep:653 epch:13.05 loss:0.105 grdn:9.078 lr:1.0e-05 updt_s:0.417 data_s:0.038
# INFO 2025-12-18 10:18:55 ot_train.py:357 step:25K smpl:295K ep:658 epch:13.16 loss:0.107 grdn:8.656 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:20:24 ot_train.py:357 step:25K smpl:298K ep:663 epch:13.27 loss:0.104 grdn:8.853 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:21:54 ot_train.py:357 step:25K smpl:300K ep:669 epch:13.37 loss:0.105 grdn:8.803 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:23:24 ot_train.py:357 step:25K smpl:302K ep:674 epch:13.48 loss:0.109 grdn:9.029 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:24:53 ot_train.py:357 step:25K smpl:305K ep:679 epch:13.59 loss:0.107 grdn:9.137 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:26:23 ot_train.py:357 step:26K smpl:307K ep:685 epch:13.70 loss:0.102 grdn:8.497 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:27:53 ot_train.py:357 step:26K smpl:310K ep:690 epch:13.80 loss:0.101 grdn:8.568 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:29:22 ot_train.py:357 step:26K smpl:312K ep:695 epch:13.91 loss:0.103 grdn:8.625 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:30:53 ot_train.py:357 step:26K smpl:314K ep:701 epch:14.02 loss:0.103 grdn:8.548 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 10:32:23 ot_train.py:357 step:26K smpl:317K ep:706 epch:14.12 loss:0.098 grdn:8.369 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:33:52 ot_train.py:357 step:27K smpl:319K ep:712 epch:14.23 loss:0.103 grdn:8.613 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:35:22 ot_train.py:357 step:27K smpl:322K ep:717 epch:14.34 loss:0.098 grdn:8.313 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:36:52 ot_train.py:357 step:27K smpl:324K ep:722 epch:14.44 loss:0.103 grdn:8.891 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:38:21 ot_train.py:357 step:27K smpl:326K ep:728 epch:14.55 loss:0.102 grdn:8.510 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:39:51 ot_train.py:357 step:27K smpl:329K ep:733 epch:14.66 loss:0.101 grdn:8.773 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:41:21 ot_train.py:357 step:28K smpl:331K ep:738 epch:14.77 loss:0.100 grdn:8.186 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:42:50 ot_train.py:357 step:28K smpl:334K ep:744 epch:14.87 loss:0.101 grdn:8.507 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:44:20 ot_train.py:357 step:28K smpl:336K ep:749 epch:14.98 loss:0.100 grdn:8.286 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:45:51 ot_train.py:357 step:28K smpl:338K ep:754 epch:15.09 loss:0.098 grdn:8.225 lr:1.0e-05 updt_s:0.417 data_s:0.037
# INFO 2025-12-18 10:47:21 ot_train.py:357 step:28K smpl:341K ep:760 epch:15.19 loss:0.096 grdn:8.380 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:48:50 ot_train.py:357 step:29K smpl:343K ep:765 epch:15.30 loss:0.096 grdn:8.906 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:50:20 ot_train.py:357 step:29K smpl:346K ep:770 epch:15.41 loss:0.096 grdn:8.256 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:51:50 ot_train.py:357 step:29K smpl:348K ep:776 epch:15.51 loss:0.095 grdn:8.114 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:53:19 ot_train.py:357 step:29K smpl:350K ep:781 epch:15.62 loss:0.095 grdn:8.053 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 10:54:49 ot_train.py:357 step:29K smpl:353K ep:786 epch:15.73 loss:0.095 grdn:7.786 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 10:56:19 ot_train.py:357 step:30K smpl:355K ep:792 epch:15.84 loss:0.093 grdn:7.940 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18
lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 17:58:26 ot_train.py:357 step:86K smpl:1M ep:2K epch:46.01 loss:0.045 grdn:4.627 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 17:59:57 ot_train.py:357 step:86K smpl:1M ep:2K epch:46.12 loss:0.045 grdn:4.893 lr:1.0e-05 updt_s:0.417 data_s:0.037
# INFO 2025-12-18 18:01:27 ot_train.py:357 step:86K smpl:1M ep:2K epch:46.22 loss:0.044 grdn:4.731 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:02:56 ot_train.py:357 step:87K smpl:1M ep:2K epch:46.33 loss:0.044 grdn:4.716 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:04:26 ot_train.py:357 step:87K smpl:1M ep:2K epch:46.44 loss:0.045 grdn:4.942 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:05:56 ot_train.py:357 step:87K smpl:1M ep:2K epch:46.54 loss:0.044 grdn:4.636 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:07:25 ot_train.py:357 step:87K smpl:1M ep:2K epch:46.65 loss:0.045 grdn:4.917 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:08:55 ot_train.py:357 step:87K smpl:1M ep:2K epch:46.76 loss:0.044 grdn:4.741 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:10:25 ot_train.py:357 step:88K smpl:1M ep:2K epch:46.87 loss:0.045 grdn:4.809 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:11:54 ot_train.py:357 step:88K smpl:1M ep:2K epch:46.97 loss:0.044 grdn:4.632 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:13:25 ot_train.py:357 step:88K smpl:1M ep:2K epch:47.08 loss:0.045 grdn:4.791 lr:1.0e-05 updt_s:0.417 data_s:0.036
# INFO 2025-12-18 18:14:55 ot_train.py:357 step:88K smpl:1M ep:2K epch:47.19 loss:0.044 grdn:4.661 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:16:24 ot_train.py:357 step:88K smpl:1M ep:2K epch:47.29 loss:0.044 grdn:4.468 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:17:54 ot_train.py:357 step:89K smpl:1M ep:2K epch:47.40 loss:0.044 grdn:4.440 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:19:24 ot_train.py:357 step:89K smpl:1M ep:2K epch:47.51 loss:0.044 grdn:4.501 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:20:53 ot_train.py:357 step:89K smpl:1M ep:2K epch:47.61 loss:0.044 grdn:4.586 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:22:23 ot_train.py:357 step:89K smpl:1M ep:2K epch:47.72 loss:0.043 grdn:4.535 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:23:52 ot_train.py:357 step:89K smpl:1M ep:2K epch:47.83 loss:0.044 grdn:4.708 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:25:22 ot_train.py:357 step:90K smpl:1M ep:2K epch:47.94 loss:0.043 grdn:4.473 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:26:53 ot_train.py:357 step:90K smpl:1M ep:2K epch:48.04 loss:0.045 grdn:4.797 lr:1.0e-05 updt_s:0.418 data_s:0.036
# INFO 2025-12-18 18:28:23 ot_train.py:357 step:90K smpl:1M ep:2K epch:48.15 loss:0.044 grdn:4.399 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:29:52 ot_train.py:357 step:90K smpl:1M ep:2K epch:48.26 loss:0.043 grdn:4.651 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:31:22 ot_train.py:357 step:90K smpl:1M ep:2K epch:48.36 loss:0.042 grdn:4.432 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:32:51 ot_train.py:357 step:91K smpl:1M ep:2K epch:48.47 loss:0.043 grdn:4.840 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:34:21 ot_train.py:357 step:91K smpl:1M ep:2K epch:48.58 loss:0.043 grdn:4.317 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:35:51 ot_train.py:357 step:91K smpl:1M ep:2K epch:48.68 loss:0.043 grdn:4.542 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:37:20 ot_train.py:357 step:91K smpl:1M ep:2K epch:48.79 loss:0.044 grdn:4.976 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:38:50 ot_train.py:357 step:91K smpl:1M ep:2K epch:48.90 loss:0.043 grdn:4.383 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:40:19 ot_train.py:357 step:92K smpl:1M ep:2K epch:49.01 loss:0.045 grdn:5.047 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:41:50 ot_train.py:357 step:92K smpl:1M ep:2K epch:49.11 loss:0.043 grdn:4.233 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 18:43:20 ot_train.py:357 step:92K smpl:1M ep:2K epch:49.22 loss:0.043 grdn:4.431 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:44:50 ot_train.py:357 step:92K smpl:1M ep:2K epch:49.33 loss:0.045 grdn:4.794 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:46:19 ot_train.py:357 step:92K smpl:1M ep:2K epch:49.43 loss:0.042 grdn:4.419 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:47:49 ot_train.py:357 step:93K smpl:1M ep:2K epch:49.54 loss:0.042 grdn:4.452 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:49:19 ot_train.py:357 step:93K smpl:1M ep:2K epch:49.65 loss:0.042 grdn:4.760 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:50:48 ot_train.py:357 step:93K smpl:1M ep:2K epch:49.75 loss:0.043 grdn:4.594 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:52:18 ot_train.py:357 step:93K smpl:1M ep:2K epch:49.86 loss:0.041 grdn:4.390 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:53:47 ot_train.py:357 step:93K smpl:1M ep:2K epch:49.97 loss:0.043 grdn:4.437 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:55:18 ot_train.py:357 step:94K smpl:1M ep:3K epch:50.08 loss:0.043 grdn:4.486 lr:1.0e-05 updt_s:0.417 data_s:0.036
# INFO 2025-12-18 18:56:48 ot_train.py:357 step:94K smpl:1M ep:3K epch:50.18 loss:0.041 grdn:4.249 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 18:58:17 ot_train.py:357 step:94K smpl:1M ep:3K epch:50.29 loss:0.042 grdn:4.320 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 18:59:47 ot_train.py:357 step:94K smpl:1M ep:3K epch:50.40 loss:0.042 grdn:4.458 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:01:17 ot_train.py:357 step:94K smpl:1M ep:3K epch:50.50 loss:0.042 grdn:4.352 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:02:46 ot_train.py:357 step:95K smpl:1M ep:3K epch:50.61 loss:0.043 grdn:4.541 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:04:16 ot_train.py:357 step:95K smpl:1M ep:3K epch:50.72 loss:0.045 grdn:4.721 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:05:46 ot_train.py:357 step:95K smpl:1M ep:3K epch:50.82 loss:0.043 grdn:4.326 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:07:15 ot_train.py:357 step:95K smpl:1M ep:3K epch:50.93 loss:0.042 grdn:4.625 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:08:46 ot_train.py:357 step:95K smpl:1M ep:3K epch:51.04 loss:0.042 grdn:4.447 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 19:10:16 ot_train.py:357 step:96K smpl:1M ep:3K epch:51.15 loss:0.042 grdn:4.459 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:11:46 ot_train.py:357 step:96K smpl:1M ep:3K epch:51.25 loss:0.043 grdn:4.481 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:13:15 ot_train.py:357 step:96K smpl:1M ep:3K epch:51.36 loss:0.042 grdn:4.561 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:14:45 ot_train.py:357 step:96K smpl:1M ep:3K epch:51.47 loss:0.042 grdn:4.609 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:16:14 ot_train.py:357 step:96K smpl:1M ep:3K epch:51.57 loss:0.042 grdn:4.366 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:17:44 ot_train.py:357 step:97K smpl:1M ep:3K epch:51.68 loss:0.041 grdn:4.395 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:19:14 ot_train.py:357 step:97K smpl:1M ep:3K epch:51.79 loss:0.041 grdn:4.412 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:20:44 ot_train.py:357 step:97K smpl:1M ep:3K epch:51.89 loss:0.040 grdn:4.137 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:22:13 ot_train.py:357 step:97K smpl:1M ep:3K epch:52.00 loss:0.041 grdn:4.174 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:23:44 ot_train.py:357 step:97K smpl:1M ep:3K epch:52.11 loss:0.042 grdn:4.508 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 19:25:14 ot_train.py:357 step:98K smpl:1M ep:3K epch:52.22 loss:0.042 grdn:4.175 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:26:43 ot_train.py:357 step:98K smpl:1M ep:3K epch:52.32 loss:0.041 grdn:4.167 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:28:13 ot_train.py:357 step:98K smpl:1M ep:3K epch:52.43 loss:0.041 grdn:4.357 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:29:43 ot_train.py:357 step:98K smpl:1M ep:3K epch:52.54 loss:0.042 grdn:4.332 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:31:12 ot_train.py:357 step:98K smpl:1M ep:3K epch:52.64 loss:0.041 grdn:4.411 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:32:42 ot_train.py:357 step:99K smpl:1M ep:3K epch:52.75 loss:0.042 grdn:4.283 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:34:12 ot_train.py:357 step:99K smpl:1M ep:3K epch:52.86 loss:0.041 grdn:4.443 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:35:41 ot_train.py:357 step:99K smpl:1M ep:3K epch:52.96 loss:0.041 grdn:4.403 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:37:12 ot_train.py:357 step:99K smpl:1M ep:3K epch:53.07 loss:0.043 grdn:4.506 lr:1.0e-05 updt_s:0.418 data_s:0.037
# INFO 2025-12-18 19:38:42 ot_train.py:357 step:99K smpl:1M ep:3K epch:53.18 loss:0.042 grdn:4.279 lr:1.0e-05 updt_s:0.419 data_s:0.029
# INFO 2025-12-18 19:40:12 ot_train.py:357 step:100K smpl:1M ep:3K epch:53.29 loss:0.041 grdn:4.291 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:41:41 ot_train.py:357 step:100K smpl:1M ep:3K epch:53.39 loss:0.040 grdn:4.368 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:43:11 ot_train.py:357 step:100K smpl:1M ep:3K epch:53.50 loss:0.041 grdn:4.126 lr:1.0e-05 updt_s:0.418 data_s:0.029
# INFO 2025-12-18 19:43:11 ot_train.py:367 Checkpoint policy after step 100000
# INFO 2025-12-18 19:43:12 ot_train.py:438 End of training
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...stuff-1/model.safetensors:   0% 782k/207M [00:00<?, ?B/s]
#
# Processing Files (0 / 1)      :   0% 782k/207M [00:00<02:40, 1.28MB/s, 1.95MB/s  ]
#
# Processing Files (0 / 1)      :   1% 1.91M/207M [00:00<01:16, 2.68MB/s, 3.18MB/s  ]
# New Data Upload               :   2% 1.13M/67.1M [00:00<00:47, 1.40MB/s, 1.88MB/s  ]
#
# Processing Files (0 / 1)      :   7% 14.3M/207M [00:01<00:09, 21.3MB/s, 17.9MB/s  ]
# New Data Upload               :  10% 13.5M/134M [00:01<00:07, 17.2MB/s, 16.9MB/s  ]
#
# Processing Files (0 / 1)      :  17% 35.1M/207M [00:01<00:03, 47.0MB/s, 35.1MB/s  ]
# New Data Upload               :  26% 34.4M/134M [00:01<00:02, 40.9MB/s, 34.4MB/s  ]
#
# Processing Files (0 / 1)      :  29% 60.4M/207M [00:01<00:02, 71.4MB/s, 50.4MB/s  ]
# New Data Upload               :  30% 59.7M/201M [00:01<00:02, 64.9MB/s, 49.7MB/s  ]
#
# Processing Files (0 / 1)      :  42% 86.2M/207M [00:01<00:01, 88.9MB/s, 61.6MB/s  ]
# New Data Upload               :  41% 85.4M/206M [00:01<00:01, 83.2MB/s, 61.0MB/s  ]
#
# Processing Files (0 / 1)      :  52% 108M/207M [00:01<00:01, 95.0MB/s, 67.5MB/s  ]
# New Data Upload               :  52% 107M/206M [00:01<00:01, 90.6MB/s, 67.0MB/s  ]
#
# Processing Files (0 / 1)      :  66% 136M/207M [00:02<00:00, 108MB/s, 75.5MB/s  ]
# New Data Upload               :  66% 135M/206M [00:02<00:00, 105MB/s, 75.1MB/s  ]
#
# Processing Files (0 / 1)      :  75% 154M/207M [00:02<00:00, 104MB/s, 77.2MB/s  ]
# New Data Upload               :  75% 154M/206M [00:02<00:00, 101MB/s, 76.8MB/s  ]
#
# Processing Files (0 / 1)      :  81% 167M/207M [00:02<00:00, 90.9MB/s, 75.8MB/s  ]
# New Data Upload               :  81% 166M/206M [00:02<00:00, 89.5MB/s, 75.4MB/s  ]
#
# Processing Files (0 / 1)      :  89% 185M/207M [00:02<00:00, 90.5MB/s, 76.9MB/s  ]
# New Data Upload               :  89% 184M/206M [00:02<00:00, 89.4MB/s, 76.6MB/s  ]
#
# Processing Files (0 / 1)      : 100% 206M/207M [00:02<00:00, 95.2MB/s, 79.2MB/s  ]
# New Data Upload               : 100% 205M/206M [00:02<00:00, 94.4MB/s, 78.9MB/s  ]
#
# Processing Files (0 / 1)      : 100% 207M/207M [00:03<00:00, 67.7MB/s, 73.8MB/s  ]
# New Data Upload               : 100% 206M/206M [00:03<00:00, 67.3MB/s, 73.5MB/s  ]
#
#   ...stuff-1/model.safetensors: 100% 207M/207M [00:02<00:00, 79.2MB/s]
#
#   ...stuff-1/model.safetensors: 100% 207M/207M [00:02<00:00, 73.5MB/s]
#
# Processing Files (1 / 1)      : 100% 207M/207M [00:03<00:00, 29.8MB/s, 60.8MB/s  ]
# New Data Upload               : 100% 206M/206M [00:03<00:00, 29.7MB/s, 60.6MB/s  ]
#
#   ...stuff-1/model.safetensors: 100% 207M/207M [00:03<00:00, 64.4MB/s]
#
#   ...stuff-1/model.safetensors: 100% 207M/207M [00:03<00:00, 63.1MB/s]
#
# Processing Files (1 / 1)      : 100% 207M/207M [00:04<00:00, 51.6MB/s, 54.4MB/s  ]
# New Data Upload               : 100% 206M/206M [00:04<00:00, 51.4MB/s, 54.2MB/s  ]
#   ...stuff-1/model.safetensors: 100% 207M/207M [00:03<00:00, 60.5MB/s]
# INFO 2025-12-18 19:43:18 etrained.py:237 Model pushed to https://huggingface.co/gsubramani/move-stuff-1
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      : 100% 7.56k/7.56k [00:00<00:00, 66.6kB/s,   ???B/s  ]
#
# Processing Files (1 / 1)      : 100% 7.56k/7.56k [00:00<00:00, 37.0kB/s,  0.00B/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING 2025-12-18 19:43:19 /hf_api.py:4298 No files have been modified since last commit. Skipping to prevent empty commit.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
# Processing Files (1 / 1)      : 100% 7.56k/7.56k [00:00<00:00, 37.1kB/s,  0.00B/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING 2025-12-18 19:43:19 /hf_api.py:4298 No files have been modified since last commit. Skipping to prevent empty commit.

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli upload gsubramani/move-stuff-1 \
  /content/lerobot/outputs/train/move-stuff-1-train/checkpoints/last/pretrained_model
# Out:
# ⚠️  Warning: 'huggingface-cli upload' is deprecated. Use 'hf upload' instead.
# Start hashing 7 files.
# Finished hashing 7 files.
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
#   ...d_model/model.safetensors:  20% 41.9M/207M [00:00<?, ?B/s]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (2 / 3)      :  20% 41.9M/207M [00:00<00:00, 205MB/s,   ???B/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (2 / 3)      :  37% 75.5M/207M [00:00<00:00, 183MB/s,  167MB/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (2 / 3)      :  57% 117M/207M [00:00<00:00, 195MB/s,  189MB/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (2 / 3)      :  77% 159M/207M [00:00<00:00, 201MB/s,  196MB/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (2 / 3)      :  93% 193M/207M [00:01<00:00, 189MB/s,  189MB/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:00<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:01<00:00, 148MB/s,  165MB/s  ]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#
#
#
#   ...d_model/model.safetensors: 100% 207M/207M [00:01<00:00, 145MB/s]
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#
#
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#
#
#
# Processing Files (3 / 3)      : 100% 207M/207M [00:01<00:00, 147MB/s,  137MB/s  ]
# New Data Upload               : |          |  0.00B /  0.00B,  0.00B/s
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#   ...zer_processor.safetensors: 100% 7.56k/7.56k [00:01<?, ?B/s]
#   ...d_model/model.safetensors: 100% 207M/207M [00:01<00:00, 137MB/s]
# Removing 7 file(s) from commit that have not changed.
# No files have been modified since last commit. Skipping to prevent empty commit.
# https://huggingface.co/gsubramani/move-stuff-1/tree/main/.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
